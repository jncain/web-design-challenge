# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "NAEPData.csv"

# %%
naep = pd.read_csv(file)
naep
# Out:
#         Subject  Grade  Year     Jurisdiction  atabBasic    atabPro
# 0   Mathematics      4  2019  National public  80.045066  40.436173
# 1   Mathematics      4  2019        Minnesota  85.331833  52.852812
# 2   Mathematics      4  2017  National public  78.987811  39.544796
# 3   Mathematics      4  2017        Minnesota  85.994162  52.567884
# 4   Mathematics      4  2015  National public  81.108103  39.383061
# ..          ...    ...   ...              ...        ...        ...
# 67      Reading      4  2007        Minnesota  72.809497  36.947392
# 68      Reading      4  2005  National public  62.471555  29.768822
# 69      Reading      4  2005        Minnesota  71.372547  38.009081
# 70      Reading      4  2003  National public  61.566949  29.673930
# 71      Reading      4  2003        Minnesota  68.716037  37.211758
#
# [72 rows x 6 columns]

# %%
naep.dtypes
# Out:
# Subject          object
# Grade             int64
# Year              int64
# Jurisdiction     object
# atabBasic       float64
# atabPro         float64
# dtype: object

# %%
math_four = naep.loc[(naep["Subject"]=="Mathematics") & (naep["Grade"] == 4)]
math_eight = naep.loc[(naep["Subject"]=="Mathematics") & (naep["Grade"] == 8)]
read_four = naep.loc[(naep["Subject"]=="Reading") & (naep["Grade"] == 4)]
read_eight = naep.loc[(naep["Subject"]=="Reading") & (naep["Grade"] == 8)]

# %%
# Graph Math 4th Grade
m4_np = math_four.loc[(math_four["Jurisdiction"]=="National public")]
m4_mn = math_four.loc[(math_four["Jurisdiction"]=="Minnesota")]

xlabels = m4_mn['Year']
npcolor = '#c69214'
mncolor = '#001871'
fig, ax = plt.subplots(figsize=(14, 8))

mn, = plt.plot(m4_mn['Year'], m4_mn["atabPro"], marker='o', markerfacecolor=mncolor, markeredgecolor=mncolor, markersize=8, color=mncolor, linewidth=4, label="Minnesota")
np, = plt.plot(m4_np['Year'], m4_np["atabPro"], marker='o', markerfacecolor=npcolor, markeredgecolor=npcolor, markersize=8, color=npcolor, linewidth=4, label="National public")

plt.tick_params(axis='both', labelsize=14)
plt.ylim(0, 100)
plt.xticks(xlabels)

leg = plt.legend(fontsize=16)
leg.set_title('Jurisdiction:', prop={'size':16, 'weight':'bold'})
plt.title("Results for 4th Grade Students on NAEP Mathematics", fontsize=20, fontweight='bold')
plt.xlabel("Year", fontsize=18, fontweight='bold')
plt.ylabel("Percent of Students\n at or above NAEP Proficient", fontsize=18, fontweight='bold')

plt.savefig("WebVisualizations/assets/Grade4Math.png")

plt.show()

# %%
# Graph Math 8th Grade
m8_np = math_eight.loc[(math_eight["Jurisdiction"]=="National public")]
m8_mn = math_eight.loc[(math_eight["Jurisdiction"]=="Minnesota")]

xlabels = m8_mn['Year']
npcolor = '#c69214'
mncolor = '#001871'
fig, ax = plt.subplots(figsize=(14, 8))

mn, = plt.plot(m8_mn['Year'], m8_mn["atabPro"], marker='o', markerfacecolor=mncolor, markeredgecolor=mncolor, markersize=8, color=mncolor, linewidth=4, label="Minnesota")
np, = plt.plot(m8_np['Year'], m8_np["atabPro"], marker='o', markerfacecolor=npcolor, markeredgecolor=npcolor, markersize=8, color=npcolor, linewidth=4, label="National public")

plt.tick_params(axis='both', labelsize=14)
plt.ylim(0, 100)
plt.xticks(xlabels)

leg = plt.legend(fontsize=16)
leg.set_title('Jurisdiction:', prop={'size':16, 'weight':'bold'})
plt.title("Results for 8th Grade Students on NAEP Mathematics", fontsize=20, fontweight='bold')
plt.xlabel("Year", fontsize=18, fontweight='bold')
plt.ylabel("Percent of Students\n at or above NAEP Proficient", fontsize=18, fontweight='bold')

plt.savefig("WebVisualizations/assets/Grade8Math.png")

plt.show()

# %%
# Graph Reading 4th Grade
r4_np = read_four.loc[(read_four["Jurisdiction"]=="National public")]
r4_mn = read_four.loc[(read_four["Jurisdiction"]=="Minnesota")]

xlabels = r4_mn['Year']
npcolor = '#c69214'
mncolor = '#001871'
fig, ax = plt.subplots(figsize=(14, 8))

mn, = plt.plot(r4_mn['Year'], r4_mn["atabPro"], marker='o', markerfacecolor=mncolor, markeredgecolor=mncolor, markersize=8, color=mncolor, linewidth=4, label="Minnesota")
np, = plt.plot(r4_np['Year'], r4_np["atabPro"], marker='o', markerfacecolor=npcolor, markeredgecolor=npcolor, markersize=8, color=npcolor, linewidth=4, label="National public")

plt.tick_params(axis='both', labelsize=14)
plt.ylim(0, 100)
plt.xticks(xlabels)

leg = plt.legend(fontsize=16)
leg.set_title('Jurisdiction:', prop={'size':16, 'weight':'bold'})
plt.title("Results for 4th Grade Students on NAEP Reading", fontsize=20, fontweight='bold')
plt.xlabel("Year", fontsize=18, fontweight='bold')
plt.ylabel("Percent of Students\n at or above NAEP Proficient", fontsize=18, fontweight='bold')

plt.savefig("WebVisualizations/assets/Grade4Read.png")

plt.show()

# %%
# Graph Math 8th Reading
r8_np = read_eight.loc[(read_eight["Jurisdiction"]=="National public")]
r8_mn = read_eight.loc[(read_eight["Jurisdiction"]=="Minnesota")]

xlabels = r8_mn['Year']
npcolor = '#c69214'
mncolor = '#001871'
fig, ax = plt.subplots(figsize=(14, 8))

mn, = plt.plot(r8_mn['Year'], r8_mn["atabPro"], marker='o', markerfacecolor=mncolor, markeredgecolor=mncolor, markersize=8, color=mncolor, linewidth=4, label="Minnesota")
np, = plt.plot(r8_np['Year'], r8_np["atabPro"], marker='o', markerfacecolor=npcolor, markeredgecolor=npcolor, markersize=8, color=npcolor, linewidth=4, label="National public")

plt.tick_params(axis='both', labelsize=14)
plt.ylim(0, 100)
plt.xticks(xlabels)

leg = plt.legend(fontsize=16)
leg.set_title('Jurisdiction:', prop={'size':16, 'weight':'bold'})
plt.title("Results for 8th Grade Students on NAEP Reading", fontsize=20, fontweight='bold')
plt.xlabel("Year", fontsize=18, fontweight='bold')
plt.ylabel("Percent of Students\n at or above NAEP Proficient", fontsize=18, fontweight='bold')

plt.savefig("WebVisualizations/assets/Grade8Read.png")

plt.show()
